# %%
import anywidget
import traitlets

class CounterWidget(anywidget.AnyWidget):
    _esm = "index.js"
    _css = "index.css"
    value = traitlets.Int(0).tag(sync=True)

CounterWidget(value=42)
# Out:
# CounterWidget(value=42)
